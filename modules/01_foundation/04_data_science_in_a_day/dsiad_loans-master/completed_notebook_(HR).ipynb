# %% [markdown]
# # Load necessary libraries

# %%
# Import pandas library for data reading and manipulation
import pandas as pd

# Import numpy for maths functions 
import numpy as np

# Import seaborn to visualise and explore your data
import seaborn as sns

# Import to visualise decision tree
import pydotplus
import graphviz

# Import decision tree function from sklearn
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# To display graphs right here in our notebook!
# %matplotlib inline

# %% [markdown]
# # Read the HR data into Jupyter notebook

# %%
# Use the read_csv function in Pandas to read the HR file into Python
hr = pd.read_csv('HR_data - HR_data.csv')

# %%
# Let's see what our data looks like
hr.tail()
# Out:
#       salary  satisfaction_level  last_evaluation  number_project  \
# 9611   81000                0.43             0.50               2
# 9612   78000                0.69             0.73               4
# 9613   81000                0.88             0.55               4
# 9614   86000                0.67             0.49               3
# 9615   84000                0.78             0.60               4
#
#       average_monthly_hours  time_spend_company  work_accident  \
# 9611                    137                   3              0
# 9612                    257                  10              1
# 9613                    205                   4              0
# 9614                    185                   3              0
# 9615                    206                   3              0
#
#       promotion_last_5years  resigned
# 9611                      0         1
# 9612                      0         0
# 9613                      0         0
# ...

# %% [markdown]
# # Explore the data

# %%
sns.pairplot(hr)

# %% [markdown]
# # Build decision tree model!

# %%
# Train our decision tree with a maximum depth of 3
dtree = DecisionTreeClassifier(max_depth= 3)

dtree.fit(hr.drop(['resigned'], axis= 1), hr['resigned'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Let's define a function for plotting our decision tree!
dot_data = export_graphviz(dtree, 
                                out_file=None, 
                                feature_names=hr.drop(['resigned'], axis =1).columns,
                                filled=True, 
                                rounded=True, class_names = ['Yes',"no"])
graph = graphviz.Source(dot_data)

# %%
graph
